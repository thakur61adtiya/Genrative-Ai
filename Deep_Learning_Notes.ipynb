# %%
# DEEP LEARNING >>>>> it is a subset of AI and ML . it is based on logical structure is known as neural network , this neural network inspired by human brain .
# problem ----> Result prediction -->> x1               x2                 y
#                                      python maeks   Gen AI marks        result
#                                       20                30               0
#                                       50                60               1
# 0 is a neuron or prediction...
# what is perceptron >>>> it is a algorihm or set of rules. it is a simple model of neuron in artifical neurol network.
# Percenptron recieve input multiply , this input multiply by weight then add bias and apply activation function.
# z = x1w1 + x2w2 + b ---->>> z>=0-->>1(true) , z<0--->>0(false)
# Activation functions --- it is mathematical functions, which is applied on neuron. it is represent non-linearty in the data.It determines the output of neuron.
# Sigmoid activation functions ---->>> it is work on binary classifacation based probelms.
# y = sigma(z) = 1/1+L^-2 -->>> z = -infinity to +infinity, y(range) = (O TO 1)
# Tanh activation function --->> y=tanhz = l^2 - l^-2 / l^2 + l^-2 ,, range (-1 to 1) , Domain (Z) -infinity to +infinity
