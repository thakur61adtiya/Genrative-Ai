# %%
x = 10
x
# Out:
# 10

# %%
y = 20
y
# Out:
# 20

# %%
my_sub = "Generative AI"
print(my_sub)
# Out:
# Generative AI

# %%
_mycity = "solan"
_mycity
# Out:
# 'solan'

# %%
my_college = "shoolini"
my_college
# Out:
# 'shoolini'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']
