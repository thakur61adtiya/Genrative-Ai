# %%
# single quotes system
my_sub = 'machine learning'
type(my_sub)
# Out:
# str

# %%
my_college = "shoolini university"
type(my_college)
# Out:
# str

# %%
my_sentence = ''' this sntence is multiple line,
this is also known as string '''
type(my_sentence)
# Out:
# str

# %%
#find the lentgth of string
my_sub = 'machine learning'
len(my_sub)
# Out:
# 16

# %%
my_sub = "machine learning"
my_sub[0]
# Out:
# 'm'

# %%
my_sub[2]
# Out:
# 'c'

# %%
my_sub[-2]
# Out:
# 'n'

# %%
my_sub[-5]
# Out:
# 'r'

# %%
my_sub = "machine learning"
my_sub[:4]
# Out:
# 'mach'

# %%
my_sub[8:16:1]
# Out:
# 'learning'

# %%
my_sub = "PYTHON"
my_sub.lower()
# Out:
# 'python'

# %%
my_sub = "python"
my_sub.upper()
# Out:
# 'PYTHON'

# %%
my_string = "machine learning"
my_string.count('a')
# Out:
# 2

# %%
my_string = "machine learning"
my_string.count('n')
# Out:
# 3

# %%
my_list = [78 , 45 , 67 , 78] # homogenous list
type(my_list)
# Out:
# list

# %%
mixed_list = [23 , 3.25 , None , "apple" , True] # heterogenous list
type(mixed_list)
# Out:
# list

# %%
#find the length of list
mixed_list = [ None  , 6 ,"mango"  , 23 , 56 , False , 34 ]
len(mixed_list)
# Out:
# 7

# %%
my_list = [78 , 39 , 23 , 84 , 10]
print(my_list[3])
# Out:
# 84

# %%
my_list = [78 , 89 , 23 , 34 , 10]
print(my_list[0])
print(my_list[1])
print(my_list[2])
print(my_list[3])
print(my_list[4])
# Out:
# 78
# 89
# 23
# 34
# 10

# %%
my_list = [78 , 89 , 23 , 34 , 10]
print(my_list[-1])
print(my_list[-2])
print(my_list[-3])
print(my_list[-4])
print(my_list[-5])
# Out:
# 10
# 34
# 23
# 89
# 78

# %%
my_list = [2,3,7,1,9,5]
my_list[0:5:1]
# Out:
# [2, 3, 7, 1, 9]

# %%
#by default stepsize is one
my_list = [2,3,7,1,9,5]
my_list[0:5]
# Out:
# [2, 3, 7, 1, 9]

# %%
my_list[:5]
# Out:
# [2, 3, 7, 1, 9]

# %%
my_list[0:]
# Out:
# [2, 3, 7, 1, 9, 5]

# %%
# funtion in list
my_list = [ 24 , 45 , 6 , 3]
min(my_list)
# Out:
# 3

# %%
max(my_list)
# Out:
# 45

# %%
sum(my_list)
# Out:
# 78

# %%
list1 = [9 , 7 , 12 , 4 , 8 , 3]
sorted(list1)
# Out:
# [3, 4, 7, 8, 9, 12]

# %%
sorted(list1 , reverse = True)
# Out:
# [12, 9, 8, 7, 4, 3]

# %%
list = [23 , 56 , 34 , 2 , 46 , 56 , 78 , 8 ]
sorted(list , reverse = True)
# Out:
# [78, 56, 56, 46, 34, 23, 8, 2]

# %%
my_list = [ 2 , 3 , 5 , 3]
my_list.extend(["suryansh" , "bhavoria"])
print(my_list)
len(my_list)
# Out:
# [2, 3, 5, 3, 'suryansh', 'bhavoria']
# 6
