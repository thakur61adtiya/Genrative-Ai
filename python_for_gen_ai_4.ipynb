# %%
my_list = [90 , 87 , 65 , 34]
print(my_list)
my_list.append(100)
print(my_list)
# Out:
# [90, 87, 65, 34]
# [90, 87, 65, 34, 100]

# %%
my_list[2] = 200
print(my_list)
# Out:
# [90, 87, 200, 34, 100]

# %%
list1 = [90 , 78 , 65]
list2 = [56 , 89 , 45]
list1.extend(list2)
print(list1)
# Out:
# [90, 78, 65, 56, 89, 45]

# %%
my_list = [ 78 , 56 , 34 , 12]
my_list.pop(3)
print(my_list)
# Out:
# [78, 56, 34]

# %%
list1 = [90 , 87 , 65 , 23]
list1.remove(23)
print(list1)
# Out:
# [90, 87, 65]

# %%
my_list = [90 , 65 , 47 , 34]
my_list.reverse()
print(my_list)
# Out:
# [34, 47, 65, 90]

# %%
#Dictionary
my_dict = {"Name":"Suryansh" , "College":"Shollini university"}
type(my_dict)
# Out:
# dict

# %%
print(my_dict)
# Out:
# {'Name': 'Suryansh', 'College': 'Shollini university'}

# %%
print(my_dict["Name"])
print(my_dict["College"])
# Out:
# Suryansh
# Shollini university

# %%
my_dict.keys()
# Out:
# dict_keys(['Name', 'College'])

# %%
list(my_dict.keys())
# Out:
# ['Name', 'College']

# %%
my_dict.values()
# Out:
# dict_values(['Suryansh', 'Shollini university'])

# %%
list(my_dict.values())
# Out:
# ['Suryansh', 'Shollini university']

# %%
my_dict.items()
# Out:
# dict_items([('Name', 'Suryansh'), ('College', 'Shollini university')])

# %%
list(my_dict.items())
# Out:
# [('Name', 'Suryansh'), ('College', 'Shollini university')]

# %%
my_dict.get("Name")
# Out:
# 'Suryansh'

# %%
my_dict = {"Name":"Suryansh" , "College":"Shollini university" , "Age":19}
print(my_dict.get("College"))
# Out:
# Shollini university

# %%
my_dict = {"Name":"Suryansh" , "College":"Shollini university" , "Age":19}
print(my_dict.get("Age"))
# Out:
# 19

# %%
my_dict.update({"Age":20})
print(my_dict)
# Out:
# {'Name': 'Suryansh', 'College': 'Shollini university', 'Age': 20}

# %%
my_dict.update({"Name2":"Honey"})
print(my_dict)
# Out:
# {'Name': 'Suryansh', 'College': 'Shollini university', 'Age': 19, 'Name2': 'Honey'}

# %%
list = [ 34 , 4 , 56 , 67 , 56 , 23 , 45 , 67 ]
sorted(list,reverse =True)
# Out:
# [67, 67, 56, 56, 45, 34, 23, 4]

# %%
my_list = [12 , 35 , 23 , 45 , 67 , 89 , 53 , 67 , 124 , 34 ]
my_list.reverse()
print(my_list)
# Out:
# [34, 124, 67, 53, 89, 67, 45, 23, 35, 12]

# %%
list1 = [ 2 , 5 , 6 ]
list2 = [ 9 , 4 , 7 ]
list3 = [ 2 , 4 , 6 ]
list_of_list = [list1 , list2 , list3 ]
print(list_of_list)
# Out:
# [[2, 5, 6], [9, 4, 7], [2, 4, 6]]
