# %%
# pandas
import pandas as pd

# %%
# series >>>> one dimenstional data structure of pandas
my_series = pd.Series(["Apple" , "Banana" , "Mango" , "Orange"])
my_series.name="Fruit"
my_series
# Out:
# 0     Apple
# 1    Banana
# 2     Mango
# 3    Orange
# Name: Fruit, dtype: object

# %%
# Data frame >>>> two dimenstional data structure in pandas
list_into_list = [["Amar",15] , ["Akbar",16] , ["Anthony" , 26]]
df=pd.DataFrame(list_into_list , columns=["Name" , "Age"])
df
# Out:
#       Name  Age
# 0     Amar   15
# 1    Akbar   16
# 2  Anthony   26

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Data/imdb_data.csv")
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
# head ()--- bring rows (data point) from top of the dtaframe
df.head() # by default it prints 5 rows
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.head(100)
# Out:
#      id                              belongs_to_collection    budget  \
# 0     1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1     2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2     3                                                NaN   3300000
# 3     4                                                NaN   1200000
# 4     5                                                NaN         0
# ..  ...                                                ...       ...
# 95   96                                                NaN         0
# 96   97                                                NaN   2500000
# 97   98                                                NaN         0
# 98   99                                                NaN  10500000
# 99  100                                                NaN   6000000
#
#                                                genres  \
# 0                      [{'id': 35, 'name': 'Comedy'}]
# ...

# %%
# tail()-- bring the rows (data point) from bottom of the data fram
df.tail() # by default 5 rows from bottom
# Out:
#         id belongs_to_collection    budget  \
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2995                               NaN  tt0109403                en
# 2996                               NaN  tt2364975                sv
# 2997                               NaN  tt0116908                en
# 2998    http://www.alongcamepolly.com/  tt0343135                en
# ...

# %%
df.tail(100)
# Out:
#         id                              belongs_to_collection    budget  \
# 2900  2901                                                NaN    200000
# 2901  2902                                                NaN  75000000
# 2902  2903  [{'id': 207621, 'name': 'V/H/S Collection', 'p...         0
# 2903  2904                                                NaN  16000000
# 2904  2905  [{'id': 424202, 'name': 'Trainspotting Collect...   4000000
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
# find the number of rows and columns in the data frame
df.shape # 3000 represent the rows 23 represent the columns
# Out:
# (3000, 23)

# %%
# to find the name of the all columns
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
# bring the rows randomly from the data
df.sample(5)
# Out:
#         id belongs_to_collection   budget  \
# 2416  2417                   NaN  2500000
# 50      51                   NaN   560000
# 1714  1715                   NaN  5000000
# 929    930                   NaN  5000000
# 2261  2262                   NaN        0
#
#                                                  genres  \
# 2416  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 50    [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 1714  [{'id': 35, 'name': 'Comedy'}, {'id': 99, 'nam...
# 929   [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 2261  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                                      homepage    imdb_id original_language  \
# 2416       http://knockknockmovie.tumblr.com/  tt3605418                en
# 50    http://www.moscow-belgium.com/index.php  tt0948530                nl
# 1714                                      NaN  tt0084156                en
# ...

# %%
# find the information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
# how does the data look like mathematically
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
# find the duplicate value
print(df.duplicated().sum())
# Out:
# 0

# %%
# find the null value
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
# slicing and indexing
# find the single column with all row
df["title"]
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %%
# multiple columns with all rows
df[["title" , "budget" , "revenue" , 'original_language' ]]
# Out:
#                                          title    budget    revenue  \
# 0                       Hot Tub Time Machine 2  14000000   12314651
# 1     The Princess Diaries 2: Royal Engagement  40000000   95149435
# 2                                     Whiplash   3300000   13092000
# 3                                      Kahaani   1200000   16000000
# 4                                   Marine Boy         0    3923970
# ...                                        ...       ...        ...
# 2995                                   Chasers         0    1596687
# 2996                          We Are the Best!         0     180590
# 2997                   The Long Kiss Goodnight  65000000   89456761
# 2998                          Along Came Polly  42000000  171963386
# 2999                                 Abduction  35000000   82087155
#
#      original_language
# 0                   en
# 1                   en
# 2                   en
# 3                   hi
# 4                   ko
# ...

# %%
# slicing with the help of rows
df[0:4]
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
#
# ...

# %%
# to find the sum number of thr rows and columns
df.iloc[0:4 , 0:3]
# Out:
#    id                              belongs_to_collection    budget
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000

# %%
# loc method
df.loc[0:4 , ["title" , "budget" , "revenue"]]
# Out:
#                                       title    budget   revenue
# 0                    Hot Tub Time Machine 2  14000000  12314651
# 1  The Princess Diaries 2: Royal Engagement  40000000  95149435
# 2                                  Whiplash   3300000  13092000
# 3                                   Kahaani   1200000  16000000
# 4                                Marine Boy         0   3923970

# %%
# find the unique value in particular column
df["original_language"].unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id'], dtype=object)

# %%
df["original_language"] == "en" # comparison operator gives the output in the form of True and False
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
english_movie = df[df["original_language"] == "en"]
english_movie
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 5        6                                                NaN   8000000
# 6        7                                                NaN  14000000
# ...    ...                                                ...       ...
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
# how to write file in csv format
english_movie.to_csv("english_movie.csv")
