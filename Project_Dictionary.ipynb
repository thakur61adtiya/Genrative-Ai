# %%
# DICTIONARY
my_dict = {"Name_1" : "Suryansh Bhavoria" , "Name_2" : "Karan Thakur" , "Name_3" : "Honey Manhas" , "Name_4" : "Sahil Patial" , "Name_5" : "Ashwin Chandel" , "Name_6" : "Apurav Chandel" ,
"College_1" : "Shoolini University" , "College_2" : "Pol Tech" , "College_3" : "Civil Engeneering College" , "College_4" : "LPU" , "College_5" : "Government College" , "College_6" : "Shwami Viveknand College" ,
"Age_1" : "18" , "Age_2" : "18" , "Age_3" : "19" , "Age_4" : "19" , "Age_5" : "18"}
print(my_dict)
# Out:
# {'Name_1': 'Suryansh Bhavoria', 'Name_2': 'Karan Thakur', 'Name_3': 'Honey Manhas', 'Name_4': 'Sahil Patial', 'Name_5': 'Ashwin Chandel', 'Name_6': 'Apurav Chandel', 'College_1': 'Shoolini University', 'College_2': 'Pol Tech', 'College_3': 'Civil Engeneering College', 'College_4': 'LPU', 'College_5': 'Government College', 'College_6': 'Shwami Viveknand College', 'Age_1': '18', 'Age_2': '18', 'Age_3': '19', 'Age_4': '19', 'Age_5': '18'}

# %%
print(my_dict.keys())
# Out:
# dict_keys(['Name_1', 'Name_2', 'Name_3', 'Name_4', 'Name_5', 'Name_6', 'College_1', 'College_2', 'College_3', 'College_4', 'College_5', 'College_6', 'Age_1', 'Age_2', 'Age_3', 'Age_4', 'Age_5'])

# %%
print(my_dict.values())
# Out:
# dict_values(['Suryansh Bhavoria', 'Karan Thakur', 'Honey Manhas', 'Sahil Patial', 'Ashwin Chandel', 'Apurav Chandel', 'Shoolini University', 'Pol Tech', 'Civil Engeneering College', 'LPU', 'Government College', 'Shwami Viveknand College', '18', '18', '19', '19', '18'])

# %%
print(my_dict.items())
# Out:
# dict_items([('Name_1', 'Suryansh Bhavoria'), ('Name_2', 'Karan Thakur'), ('Name_3', 'Honey Manhas'), ('Name_4', 'Sahil Patial'), ('Name_5', 'Ashwin Chandel'), ('Name_6', 'Apurav Chandel'), ('College_1', 'Shoolini University'), ('College_2', 'Pol Tech'), ('College_3', 'Civil Engeneering College'), ('College_4', 'LPU'), ('College_5', 'Government College'), ('College_6', 'Shwami Viveknand College'), ('Age_1', '18'), ('Age_2', '18'), ('Age_3', '19'), ('Age_4', '19'), ('Age_5', '18')])

# %%
my_dict ="Name_3"
type(my_dict)
# Out:
# str

# %%
print(my_dict.get("Age_2"))
# Out:
# 18

# %%
my_dict.update({"Age_6" : 19})
print(my_dict)
# Out:
# {'Name_1': 'Suryansh Bhavoria', 'Name_2': 'Karan Thakur', 'Name_3': 'Honey Manhas', 'Name_4': 'Sahil Patial', 'Name_5': 'Ashwin Chandel', 'Name_6': 'Apurav Chandel', 'College_1': 'Shoolini University', 'College_2': 'Pol Tech', 'College_3': 'Civil Engeneering College', 'College_4': 'LPU', 'College_5': 'Government College', 'College_6': 'Shwami Viveknand College', 'Age_1': '18', 'Age_2': '18', 'Age_3': '19', 'Age_4': '19', 'Age_5': '18', 'Age_6': 19}
