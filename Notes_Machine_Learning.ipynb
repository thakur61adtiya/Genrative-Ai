# %%
# supervised machine learning >>>> it is type of machine learning which is deal with label data type.It is solve two types of probelms
# (1) Regression based probelms (2) classificaton based probelms
# Regression probelms ----- the output feature in regression probelms is in countinous form . ex.-- package prediction.
# cgpa     package
# 10        9.5
# 8         8.6
# 9         9
# supervised ML. algorithms solved Regression based probelms
# (1)Linear regression (2) Ridge regression (3) Support vectoer regression (4) decision tree regression (5) Random forest regression
# Classification probelms >>>> the output feature of this type of probelms is dicreate.
# ex ---> result prediction ( Binary classification )
# marks     result
# 90         P >> 1
# 30         F >> 0
# 25         F >> 0
# 60         P >> 1

# %%
# classification of suoervised ML algorithm based probelms
# (1) logistic regression (2) support vector classification (3) decission tree classification (4)Random forest classification
# (1) Spam email detection (2) disease prediction

# %%
# unsupervised learning >>>> it is deal with unlabeled data
# it is solved following probelms
# (1) clustring ---> grouping ---> ex. customer segmentation (2) dimenstional reduction (3) anomaly detection (4) association

# %%
# Linear regression >>>> it is supervised ML algorithm which is solved regression based problem , thre are three types of linear regression
# (1) simple linear regression( y = ms + c ) (2) multi linear regression( y = m1x1+m2x2+c) (3) polynomial linear regression (y = b0+B1x1+b1x1^2)
# what is simple regression?? >>> y = mx+b

# %%
# Relu activation function ---->>> y = max(0,z)   range --- 0 to infinity , domain --- -infinity to +infinity
# Leaky Relu activation function ---->>> it is a solved dead neuron problem
# y = max(0.01z to z) ,, y = -infinity to +infinity ,, domain = -infinity to +infinity
# Single preceptron not work on non linear data but multi preceptron work on non linear data . multilayer perceptron ----> Artificial neural network(ANN) .

# %%
#(1) relu activation function in ANN used in hidden layer.(2)if your problem is binary classification based then uesd sigmoid activation function in output layer.
#(3) if your porblem is multi classification based then used soft max activation function.

# %%
# Forward propegation --->> in forward propegation basically we took the input multiply by the weight then add bias , aplly activation function
# this entire process ,we do till the end.
# Loss function : it is mathematical function that measure how well a model prediction match the actual value. --->> L = y-Y^
# loss function in regression based problems --- >> 1. mean squared error (MSC) 2. mean absolute error (MAE) 3.

# %%
# Loss function in classification based probelms --->
# (1) Binary cross entropy --> Binary classifiction baesd probelms.
# (2) categorical cross entropy ---> multiclassifiction based problem.
# Backward propegation ---> it is a gradient estimation method commenly used for training a neural network to compute its parameter updates .
# (1) Weight updation formula.(2) Bias updation formula.
# Learning rate ---> it is a hyper parameter that control the size of the weight adjustment during each itration of training.
#
