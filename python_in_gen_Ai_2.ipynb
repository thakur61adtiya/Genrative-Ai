# %%
x = 1
type(x)
# Out:
# int

# %%
y = 4.6
type(y)
# Out:
# float

# %%
z = 3 + 4j
type(z)
# Out:
# complex

# %%
a = "solan"
type(a)
# Out:
# str

# %%
x = True
type(x)
# Out:
# bool

# %%
y = False
type(y)
# Out:
# bool

# %%
e = None
type(e)
# Out:
# NoneType

# %%
2 + 2
print(2 + 2)
# Out:
# 4

# %%
4 - 2
print(4 - 2)
# Out:
# 2

# %%
#multipilaction
7 * 3
print(7 * 3)
# Out:
# 21

# %%
#division
a = 4
b = 3
c = a / b
print(c)
# Out:
# 1.3333333333333333

# %%
#exponation
2 ** 4
print(2 ** 4)
# Out:
# 16

# %%
#float divison
7 // 2
# Out:
# 3

# %%
7 // 2
# Out:
# 3

# %%
7.4 // 4
# Out:
# 1.0

# %%
#modulus--- gives always remainder
5%2
# Out:
# 1
